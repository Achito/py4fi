# %%
import numpy as np
import pandas as pd
from pylab import mpl, plt
plt.style.use('seaborn')
mpl.rcParams['font.family'] = 'sherif'
# %matplotlib inline

# %%
filename = './tr_eikon_eod_data.csv'

# %%
f = open(filename, 'r')
f.readlines()[:5]
# Out:
# ['Date,AAPL.O,MSFT.O,INTC.O,AMZN.O,GS.N,SPY,.SPX,.VIX,EUR=,XAU=,GDX,GLD\n',
#  '2010-01-04,30.57282657,30.95,20.88,133.9,173.08,113.33,1132.99,20.04,1.4411,1120.0,47.71,109.8\n',
#  '2010-01-05,30.625683660000004,30.96,20.87,134.69,176.14,113.63,1136.52,19.35,1.4368,1118.65,48.17,109.7\n',
#  '2010-01-06,30.138541290000003,30.77,20.8,132.25,174.26,113.71,1137.14,19.16,1.4412,1138.5,49.34,111.51\n',
#  '2010-01-07,30.082827060000003,30.452,20.6,130.0,177.67,114.19,1141.69,19.06,1.4318,1131.9,49.1,110.82\n']

# %%
data = pd.read_csv(filename, index_col=0, parse_dates=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1972 entries, 2010-01-04 to 2017-10-31
# Data columns (total 12 columns):
# AAPL.O    1972 non-null float64
# MSFT.O    1972 non-null float64
# INTC.O    1972 non-null float64
# AMZN.O    1972 non-null float64
# GS.N      1972 non-null float64
# SPY       1972 non-null float64
# .SPX      1972 non-null float64
# .VIX      1972 non-null float64
# EUR=      1972 non-null float64
# XAU=      1972 non-null float64
# GDX       1972 non-null float64
# GLD       1972 non-null float64
# dtypes: float64(12)
# memory usage: 200.3 KB

# %%
data
# Out:
#                 AAPL.O  MSFT.O  INTC.O   AMZN.O    GS.N     SPY     .SPX  \
# Date
# 2010-01-04   30.572827  30.950   20.88   133.90  173.08  113.33  1132.99
# 2010-01-05   30.625684  30.960   20.87   134.69  176.14  113.63  1136.52
# 2010-01-06   30.138541  30.770   20.80   132.25  174.26  113.71  1137.14
# 2010-01-07   30.082827  30.452   20.60   130.00  177.67  114.19  1141.69
# 2010-01-08   30.282827  30.660   20.83   133.52  174.31  114.57  1144.98
# ...                ...     ...     ...      ...     ...     ...      ...
# 2017-10-25  156.410000  78.630   40.78   972.91  241.71  255.29  2557.15
# 2017-10-26  157.410000  78.760   41.35   972.43  241.72  255.62  2560.40
# 2017-10-27  163.050000  83.810   44.40  1100.95  241.71  257.71  2581.07
# 2017-10-30  166.720000  83.890   44.37  1110.85  240.89  256.75  2572.83
# 2017-10-31  169.040000  83.180   45.49  1105.28  242.48  257.15  2575.26
#
#              .VIX    EUR=     XAU=    GDX     GLD
# Date
# 2010-01-04  20.04  1.4411  1120.00  47.71  109.80
# 2010-01-05  19.35  1.4368  1118.65  48.17  109.70
# 2010-01-06  19.16  1.4412  1138.50  49.34  111.51
# 2010-01-07  19.06  1.4318  1131.90  49.10  110.82
# 2010-01-08  18.13  1.4412  1136.10  49.84  111.37
# ...           ...     ...      ...    ...     ...
# 2017-10-25  11.23  1.1812  1277.01  22.83  121.35
# 2017-10-26  11.30  1.1650  1266.73  22.43  120.33
# 2017-10-27   9.80  1.1608  1272.60  22.57  120.90
# 2017-10-30  10.50  1.1649  1275.86  22.76  121.13
# 2017-10-31  10.18  1.1644  1271.20  22.48  120.67
#
# [1972 rows x 12 columns]

# %%
data.head()
# Out:
#                AAPL.O  MSFT.O  INTC.O  AMZN.O    GS.N     SPY     .SPX   .VIX  \
# Date
# 2010-01-04  30.572827  30.950   20.88  133.90  173.08  113.33  1132.99  20.04
# 2010-01-05  30.625684  30.960   20.87  134.69  176.14  113.63  1136.52  19.35
# 2010-01-06  30.138541  30.770   20.80  132.25  174.26  113.71  1137.14  19.16
# 2010-01-07  30.082827  30.452   20.60  130.00  177.67  114.19  1141.69  19.06
# 2010-01-08  30.282827  30.660   20.83  133.52  174.31  114.57  1144.98  18.13
#
#               EUR=     XAU=    GDX     GLD
# Date
# 2010-01-04  1.4411  1120.00  47.71  109.80
# 2010-01-05  1.4368  1118.65  48.17  109.70
# 2010-01-06  1.4412  1138.50  49.34  111.51
# 2010-01-07  1.4318  1131.90  49.10  110.82
# 2010-01-08  1.4412  1136.10  49.84  111.37

# %%
data.tail()
# Out:
#             AAPL.O  MSFT.O  INTC.O   AMZN.O    GS.N     SPY     .SPX   .VIX  \
# Date
# 2017-10-25  156.41   78.63   40.78   972.91  241.71  255.29  2557.15  11.23
# 2017-10-26  157.41   78.76   41.35   972.43  241.72  255.62  2560.40  11.30
# 2017-10-27  163.05   83.81   44.40  1100.95  241.71  257.71  2581.07   9.80
# 2017-10-30  166.72   83.89   44.37  1110.85  240.89  256.75  2572.83  10.50
# 2017-10-31  169.04   83.18   45.49  1105.28  242.48  257.15  2575.26  10.18
#
#               EUR=     XAU=    GDX     GLD
# Date
# 2017-10-25  1.1812  1277.01  22.83  121.35
# 2017-10-26  1.1650  1266.73  22.43  120.33
# 2017-10-27  1.1608  1272.60  22.57  120.90
# 2017-10-30  1.1649  1275.86  22.76  121.13
# 2017-10-31  1.1644  1271.20  22.48  120.67

# %%
data.plot(figsize=(10,6), subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x118e441d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x118e67c90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x119bfb2d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x119c30910>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x119c6f190>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x119ca4650>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x119cd9cd0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x119d1b810>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x119d25490>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x119d57a50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x119dc6750>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x119df8dd0>],
#       dtype=object)
# findfont: Font family ['sherif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sherif'] not found. Falling back to DejaVu Sans.

# %%
data.mean()
# Out:
# AAPL.O      86.530152
# MSFT.O      40.586752
# INTC.O      27.701411
# AMZN.O     401.154006
# GS.N       163.614625
# SPY        172.835399
# .SPX      1727.538342
# .VIX        17.209498
# EUR=         1.252613
# XAU=      1352.471593
# GDX         34.499391
# GLD        130.601856
# dtype: float64

# %%
data.aggregate([min, np.mean, np.std, np.median, max]).round(2)
# Out:
#         AAPL.O  MSFT.O  INTC.O   AMZN.O    GS.N     SPY     .SPX   .VIX  EUR=  \
# min      27.44   23.01   17.66   108.61   87.70  102.20  1022.58   9.19  1.04
# mean     86.53   40.59   27.70   401.15  163.61  172.84  1727.54  17.21  1.25
# std      34.04   14.39    5.95   257.12   37.17   42.33   424.35   5.92  0.12
# median   84.63   36.54   26.41   306.42  162.09  178.80  1783.81  15.65  1.29
# max     169.04   83.89   45.49  1110.85  252.89  257.71  2581.07  48.00  1.48
#
#            XAU=    GDX     GLD
# min     1051.36  12.47  100.50
# mean    1352.47  34.50  130.60
# std      195.38  15.44   19.46
# median  1288.82  26.59  123.90
# max     1897.10  66.63  184.59

# %%
data.diff().head()
# Out:
#               AAPL.O  MSFT.O  INTC.O  AMZN.O  GS.N   SPY  .SPX  .VIX    EUR=  \
# Date
# 2010-01-04       NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN     NaN
# 2010-01-05  0.052857   0.010   -0.01    0.79  3.06  0.30  3.53 -0.69 -0.0043
# 2010-01-06 -0.487142  -0.190   -0.07   -2.44 -1.88  0.08  0.62 -0.19  0.0044
# 2010-01-07 -0.055714  -0.318   -0.20   -2.25  3.41  0.48  4.55 -0.10 -0.0094
# 2010-01-08  0.200000   0.208    0.23    3.52 -3.36  0.38  3.29 -0.93  0.0094
#
#              XAU=   GDX   GLD
# Date
# 2010-01-04    NaN   NaN   NaN
# 2010-01-05  -1.35  0.46 -0.10
# 2010-01-06  19.85  1.17  1.81
# 2010-01-07  -6.60 -0.24 -0.69
# 2010-01-08   4.20  0.74  0.55

# %%
data.diff()
# Out:
#               AAPL.O  MSFT.O  INTC.O  AMZN.O  GS.N   SPY   .SPX  .VIX    EUR=  \
# Date
# 2010-01-04       NaN     NaN     NaN     NaN   NaN   NaN    NaN   NaN     NaN
# 2010-01-05  0.052857   0.010   -0.01    0.79  3.06  0.30   3.53 -0.69 -0.0043
# 2010-01-06 -0.487142  -0.190   -0.07   -2.44 -1.88  0.08   0.62 -0.19  0.0044
# 2010-01-07 -0.055714  -0.318   -0.20   -2.25  3.41  0.48   4.55 -0.10 -0.0094
# 2010-01-08  0.200000   0.208    0.23    3.52 -3.36  0.38   3.29 -0.93  0.0094
# ...              ...     ...     ...     ...   ...   ...    ...   ...     ...
# 2017-10-25 -0.690000  -0.230   -0.17   -2.99 -3.13 -1.27 -11.98  0.07  0.0053
# 2017-10-26  1.000000   0.130    0.57   -0.48  0.01  0.33   3.25  0.07 -0.0162
# 2017-10-27  5.640000   5.050    3.05  128.52 -0.01  2.09  20.67 -1.50 -0.0042
# 2017-10-30  3.670000   0.080   -0.03    9.90 -0.82 -0.96  -8.24  0.70  0.0041
# 2017-10-31  2.320000  -0.710    1.12   -5.57  1.59  0.40   2.43 -0.32 -0.0005
#
#              XAU=   GDX   GLD
# Date
# 2010-01-04    NaN   NaN   NaN
# 2010-01-05  -1.35  0.46 -0.10
# 2010-01-06  19.85  1.17  1.81
# 2010-01-07  -6.60 -0.24 -0.69
# 2010-01-08   4.20  0.74  0.55
# ...           ...   ...   ...
# 2017-10-25   0.68 -0.12  0.02
# 2017-10-26 -10.28 -0.40 -1.02
# 2017-10-27   5.87  0.14  0.57
# 2017-10-30   3.26  0.19  0.23
# 2017-10-31  -4.66 -0.28 -0.46
#
# [1972 rows x 12 columns]

# %%
data.pct_change().round(3).head()
# Out:
#             AAPL.O  MSFT.O  INTC.O  AMZN.O   GS.N    SPY   .SPX   .VIX   EUR=  \
# Date
# 2010-01-04     NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN    NaN
# 2010-01-05   0.002   0.000  -0.000   0.006  0.018  0.003  0.003 -0.034 -0.003
# 2010-01-06  -0.016  -0.006  -0.003  -0.018 -0.011  0.001  0.001 -0.010  0.003
# 2010-01-07  -0.002  -0.010  -0.010  -0.017  0.020  0.004  0.004 -0.005 -0.007
# 2010-01-08   0.007   0.007   0.011   0.027 -0.019  0.003  0.003 -0.049  0.007
#
#              XAU=    GDX    GLD
# Date
# 2010-01-04    NaN    NaN    NaN
# 2010-01-05 -0.001  0.010 -0.001
# 2010-01-06  0.018  0.024  0.016
# 2010-01-07 -0.006 -0.005 -0.006
# 2010-01-08  0.004  0.015  0.005

# %%
data.pct_change().mean().plot(kind='bar', figsize=(10,6))

# %%
rets = np.log(data / data.shift(1))
rets.head().round(3)
# Out:
#             AAPL.O  MSFT.O  INTC.O  AMZN.O   GS.N    SPY   .SPX   .VIX   EUR=  \
# Date
# 2010-01-04     NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN    NaN
# 2010-01-05   0.002   0.000  -0.000   0.006  0.018  0.003  0.003 -0.035 -0.003
# 2010-01-06  -0.016  -0.006  -0.003  -0.018 -0.011  0.001  0.001 -0.010  0.003
# 2010-01-07  -0.002  -0.010  -0.010  -0.017  0.019  0.004  0.004 -0.005 -0.007
# 2010-01-08   0.007   0.007   0.011   0.027 -0.019  0.003  0.003 -0.050  0.007
#
#              XAU=    GDX    GLD
# Date
# 2010-01-04    NaN    NaN    NaN
# 2010-01-05 -0.001  0.010 -0.001
# 2010-01-06  0.018  0.024  0.016
# 2010-01-07 -0.006 -0.005 -0.006
# 2010-01-08  0.004  0.015  0.005

# %%
rets.cumsum().apply(np.exp).plot(figsize=(10, 6))

# %%
data.resample('1w', label='right').last().head()
# Out:
#                AAPL.O  MSFT.O  INTC.O  AMZN.O    GS.N     SPY     .SPX   .VIX  \
# Date
# 2010-01-10  30.282827   30.66   20.83  133.52  174.31  114.57  1144.98  18.13
# 2010-01-17  29.418542   30.86   20.80  127.14  165.21  113.64  1136.03  17.91
# 2010-01-24  28.249972   28.96   19.91  121.43  154.12  109.21  1091.76  27.31
# 2010-01-31  27.437544   28.18   19.40  125.41  148.72  107.39  1073.87  24.62
# 2010-02-07  27.922829   28.02   19.47  117.39  154.16  106.66  1066.19  26.11
#
#               EUR=     XAU=    GDX     GLD
# Date
# 2010-01-10  1.4412  1136.10  49.84  111.37
# 2010-01-17  1.4382  1129.90  47.42  110.86
# 2010-01-24  1.4137  1092.60  43.79  107.17
# 2010-01-31  1.3862  1081.05  40.72  105.96
# 2010-02-07  1.3662  1064.95  42.41  104.68

# %%
rets.cumsum().apply(np.exp).resample('1m', label='right').last().plot(figsize=(10,6))

# %%
sym = 'AAPL.O'
data = pd.DataFrame(data[sym]).dropna()
data.tail()
# Out:
#             AAPL.O
# Date
# 2017-10-25  156.41
# 2017-10-26  157.41
# 2017-10-27  163.05
# 2017-10-30  166.72
# 2017-10-31  169.04

# %%
window = 20
data['min'] = data[sym].rolling(window=window).min()

# %%
data['SMA1'] = data[sym].rolling(window = 42).mean()
data['SMA2'] = data[sym].rolling(window = 252).mean()
data[[sym, 'SMA1', 'SMA2']].tail()
# Out:
#             AAPL.O        SMA1        SMA2
# Date
# 2017-10-25  156.41  157.610952  139.862520
# 2017-10-26  157.41  157.514286  140.028472
# 2017-10-27  163.05  157.517619  140.221210
# 2017-10-30  166.72  157.597857  140.431528
# 2017-10-31  169.04  157.717857  140.651766

# %%
data[[sym, 'SMA1', 'SMA2']].plot(figsize = (10, 6))

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#                 AAPL.O         min        SMA1        SMA2
# Date
# 2010-12-31   46.079954   45.348526   45.280967   37.120735
# 2011-01-03   47.081381   45.458526   45.349708   37.186246
# 2011-01-04   47.327096   45.458526   45.412599   37.252521
# 2011-01-05   47.714238   45.679597   45.466102   37.322266
# 2011-01-06   47.675667   45.679597   45.522565   37.392079
# ...                ...         ...         ...         ...
# 2017-10-25  156.410000  153.280000  157.610952  139.862520
# 2017-10-26  157.410000  153.480000  157.514286  140.028472
# 2017-10-27  163.050000  153.480000  157.517619  140.221210
# 2017-10-30  166.720000  153.480000  157.597857  140.431528
# 2017-10-31  169.040000  153.480000  157.717857  140.651766
#
# [1721 rows x 4 columns]

# %%
data['positions'] = np.where(data['SMA1'] > data['SMA2'], 1, -1)

# %%
ax = data[[sym, 'SMA1', 'SMA2', 'positions']].plot(figsize=(10, 6), secondary_y = 'positions')
ax.get_legend().set_bbox_to_anchor((0.25, 0.85))

# %%
raw = pd.read_csv('./tr_eikon_eod_data.csv', index_col=0, parse_dates=True)

# %%
data = raw[['.SPX', '.VIX']].dropna()
data.tail()
# Out:
#                .SPX   .VIX
# Date
# 2017-10-25  2557.15  11.23
# 2017-10-26  2560.40  11.30
# 2017-10-27  2581.07   9.80
# 2017-10-30  2572.83  10.50
# 2017-10-31  2575.26  10.18

# %%
data.plot(subplots=True, figsize=(10,6))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11a8998d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11b0add50>],
#       dtype=object)

# %%
data.loc[:'2012-12-31'].plot(secondary_y='.VIX', figsize=(10, 6))

# %%
rets = np.log(data / data.shift(1))

# %%
rets.head()
# Out:
#                 .SPX      .VIX
# Date
# 2010-01-04       NaN       NaN
# 2010-01-05  0.003111 -0.035038
# 2010-01-06  0.000545 -0.009868
# 2010-01-07  0.003993 -0.005233
# 2010-01-08  0.002878 -0.050024

# %%
rets.dropna(inplace=True)

# %%
rets
# Out:
#                 .SPX      .VIX
# Date
# 2010-01-05  0.003111 -0.035038
# 2010-01-06  0.000545 -0.009868
# 2010-01-07  0.003993 -0.005233
# 2010-01-08  0.002878 -0.050024
# 2010-01-11  0.001745 -0.032514
# ...              ...       ...
# 2017-10-25 -0.004674  0.006253
# 2017-10-26  0.001270  0.006214
# 2017-10-27  0.008041 -0.142420
# 2017-10-30 -0.003198  0.068993
# 2017-10-31  0.000944 -0.030950
#
# [1971 rows x 2 columns]

# %%
rets.plot(subplots = True, figsize=(10,6))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11ab61910>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11ab7b390>],
#       dtype=object)

# %%
pd.plotting.scatter_matrix(rets, alpha=0.2, diagonal='hist', hist_kwds={'bins' : 35}, figsize=(10, 6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11b1e9850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b1fab90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11b244390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11af42b90>]],
#       dtype=object)
# findfont: Font family ['sherif'] not found. Falling back to DejaVu Sans.

# %%
reg = np.polyfit(rets['.SPX'], rets['.VIX'], deg = 1)

# %%
ax = rets.plot(kind='scatter', x = '.SPX', y ='.VIX', figsize=(10, 6))
ax.plot(rets['.SPX'], np.polyval(reg, rets['.SPX']), 'r', lw=2);

# %%
rets.corr()
# Out:
#           .SPX      .VIX
# .SPX  1.000000 -0.808372
# .VIX -0.808372  1.000000

# %%
ax = rets['.SPX'].rolling(window=252).corr(rets['.VIX']).plot(figsize=(10, 6))
ax.axhline(rets.corr().iloc[0,1], c='r')

# %%
# %%time
tick = pd.read_csv('./fxcm_eur_usd_tick_data.csv', index_col = 0, parse_dates=True)
# Out:
# CPU times: user 20.9 ms, sys: 6.18 ms, total: 27 ms
# Wall time: 26.4 ms

# %%
tick.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 17352 entries, 2017-11-10 12:00:00.007000 to 2017-11-10 14:00:00.131000
# Data columns (total 2 columns):
# Bid    17352 non-null float64
# Ask    17352 non-null float64
# dtypes: float64(2)
# memory usage: 406.7 KB

# %%
tick['Mid'] = tick.mean(axis=1)

# %%
tick['Mid'].plot(figsize=(10, 6))

# %%
tick_resam = tick.resample(rule='5min', label='right').last()

# %%
tick_resam.head()
# Out:
#                          Bid      Ask       Mid
# 2017-11-10 12:05:00  1.16425  1.16427  1.164260
# 2017-11-10 12:10:00  1.16454  1.16455  1.164545
# 2017-11-10 12:15:00  1.16449  1.16449  1.164490
# 2017-11-10 12:20:00  1.16437  1.16437  1.164370
# 2017-11-10 12:25:00  1.16429  1.16430  1.164295

# %%
tick_resam['Mid'].plot(figsize=(10, 6))
