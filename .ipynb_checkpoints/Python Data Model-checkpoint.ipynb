# %%
class Vector(object):
    def __init__(self, x=0, y=0, z=0):
        self.x = x
        self.y = y
        self.z = z
    def __repr__(self):
        return 'Vector (%r,%r,%r)' % (self.x, self.y, self.z)
    
class Vector(Vector):
    def __add__(self, other):
        self.x += other.x
        self.y += other.y
        self.z += other.z
        return self

# %%
v = Vector(1,2,3)

# %%
v.add(1,1,1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-10e7d84d3a2b> in <module>
# ----> 1 v.add(1,1,1)
#
# AttributeError: 'Vector' object has no attribute 'add'
